# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
df = pd.concat([df_mat, df_por, df_geo, df_ing, df_his, df_fis, df_qui], axis=1)
df.columns = ['Mat', 'Por', 'Geo', 'Ing', 'His', 'Fis', 'Qui']

max_acertos = {'Mat': 24, 'Por': 18, 'Geo': 8, 'Ing': 8, 'His': 8, 'Fis': 12, 'Qui': 12}

for col in df.columns[0:7]:
      df[f'%_{col}'] = (df[col] / max_acertos[col]) * 100

# %%
# 2) Seu código aqui
df['Total_Acertos'] = df.iloc[:, :7].sum(axis=1)
df
# Out:
#     Mat  Por  Geo  Ing  His  Fis  Qui      %_Mat      %_Por  %_Geo  %_Ing  \
# 0     6    7    7    3    1    8    3  25.000000  38.888889   87.5   37.5
# 1    19   10    0    0    0   11    8  79.166667  55.555556    0.0    0.0
# 2    14   16    0    5    7    4    4  58.333333  88.888889    0.0   62.5
# 3    10    7    3    4    0    0    8  41.666667  38.888889   37.5   50.0
# 4     7    2    2    7    0    9    3  29.166667  11.111111   25.0   87.5
# ..  ...  ...  ...  ...  ...  ...  ...        ...        ...    ...    ...
# 95    6    4    7    1    4    9    3  25.000000  22.222222   87.5   12.5
# 96    8    1    4    6    1    4    3  33.333333   5.555556   50.0   75.0
# 97   23    5    0    2    4    1    5  95.833333  27.777778    0.0   25.0
# 98    0   10    3    1    5   10   11   0.000000  55.555556   37.5   12.5
# 99   11   15    0    1    6    7    2  45.833333  83.333333    0.0   12.5
#
#     %_His      %_Fis      %_Qui  Total_Acertos
# ...

# %%
# 3) Seu código aqui

df['%_Geral'] = df.iloc[:, :7].sum(axis=1) / 90 * 100
df
# Out:
#     Mat  Por  Geo  Ing  His  Fis  Qui      %_Mat      %_Por  %_Geo  %_Ing  \
# 0     6    7    7    3    1    8    3  25.000000  38.888889   87.5   37.5
# 1    19   10    0    0    0   11    8  79.166667  55.555556    0.0    0.0
# 2    14   16    0    5    7    4    4  58.333333  88.888889    0.0   62.5
# 3    10    7    3    4    0    0    8  41.666667  38.888889   37.5   50.0
# 4     7    2    2    7    0    9    3  29.166667  11.111111   25.0   87.5
# ..  ...  ...  ...  ...  ...  ...  ...        ...        ...    ...    ...
# 95    6    4    7    1    4    9    3  25.000000  22.222222   87.5   12.5
# 96    8    1    4    6    1    4    3  33.333333   5.555556   50.0   75.0
# 97   23    5    0    2    4    1    5  95.833333  27.777778    0.0   25.0
# 98    0   10    3    1    5   10   11   0.000000  55.555556   37.5   12.5
# 99   11   15    0    1    6    7    2  45.833333  83.333333    0.0   12.5
#
#     %_His      %_Fis      %_Qui  Total_Acertos    %_Geral
# ...

# %%
# 4) Seu código aqui
aprovados_segunda_fase = df[(df['Total_Acertos'] > 45)]
aprovados_segunda_fase
# Out:
#     Mat  Por  Geo  Ing  His  Fis  Qui      %_Mat      %_Por  %_Geo  %_Ing  \
# 1    19   10    0    0    0   11    8  79.166667  55.555556    0.0    0.0
# 2    14   16    0    5    7    4    4  58.333333  88.888889    0.0   62.5
# 5    20    2    5    3    2    9    9  83.333333  11.111111   62.5   37.5
# 7    18    4    4    7    7    1    8  75.000000  22.222222   50.0   87.5
# 8    22    9    2    7    6    5    7  91.666667  50.000000   25.0   87.5
# 17   21   15    2    2    4    2    6  87.500000  83.333333   25.0   25.0
# 18   20    4    3    5    3   11    4  83.333333  22.222222   37.5   62.5
# 20   23   11    6    5    6    2    0  95.833333  61.111111   75.0   62.5
# 24   20    2    7    5    3   11    2  83.333333  11.111111   87.5   62.5
# 27   21   13    1    5    7    3    0  87.500000  72.222222   12.5   62.5
# 31   15   13    3    1    3    9   10  62.500000  72.222222   37.5   12.5
# 35   11   14    6    3    3    0   11  45.833333  77.777778   75.0   37.5
# ...

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
#1
desqualificados = df[(df['Mat'] == 0) | (df['Fis'] == 0) | (df['Qui'] == 0)]
desqualificados
# Out:
#     Mat  Por  Geo  Ing  His  Fis  Qui      %_Mat      %_Por  %_Geo  %_Ing  \
# 3    10    7    3    4    0    0    8  41.666667  38.888889   37.5   50.0
# 6     6    0    7    7    5    0    4  25.000000   0.000000   87.5   87.5
# 10   10    8    3    2    1    7    0  41.666667  44.444444   37.5   25.0
# 12   20    8    3    7    1    0    3  83.333333  44.444444   37.5   87.5
# 14    7   11    1    7    1    4    0  29.166667  61.111111   12.5   87.5
# 20   23   11    6    5    6    2    0  95.833333  61.111111   75.0   62.5
# 25    0    4    7    4    0    4    8   0.000000  22.222222   87.5   50.0
# 26   11   14    6    2    7    0    0  45.833333  77.777778   75.0   25.0
# 27   21   13    1    5    7    3    0  87.500000  72.222222   12.5   62.5
# 33   14    8    0    5    6    6    0  58.333333  44.444444    0.0   62.5
# 35   11   14    6    3    3    0   11  45.833333  77.777778   75.0   37.5
# 49    8    1    1    0    1    0    8  33.333333   5.555556   12.5    0.0
# ...

# %%
#2
desqualificados.count()
# Out:
# Mat              23
# Por              23
# Geo              23
# Ing              23
# His              23
# Fis              23
# Qui              23
# %_Mat            23
# %_Por            23
# %_Geo            23
# %_Ing            23
# %_His            23
# %_Fis            23
# %_Qui            23
# Total_Acertos    23
# %_Geral          23
# dtype: int64

# %%
#3
mediahist = desqualificados['%_His']
display(mediahist)
mediageo = desqualificados['%_Geo']
display(mediageo)
# Out:
# 3      0.0
# 6     62.5
# 10    12.5
# 12    12.5
# 14    12.5
# 20    75.0
# 25     0.0
# 26    87.5
# 27    87.5
# 33    75.0
# 35    37.5
# 49    12.5
# 56    75.0
# 65    37.5
# 66    37.5
# 72    87.5
# 73    37.5
# 74    62.5
# 84    12.5
# 89    75.0
# 92    12.5
# 94    12.5
# 98    62.5
# Name: %_His, dtype: float64
# 3     37.5
# 6     87.5
# 10    37.5
# 12    37.5
# 14    12.5
# 20    75.0
# 25    87.5
# 26    75.0
# 27    12.5
# 33     0.0
# 35    75.0
# 49    12.5
# 56    87.5
# 65    25.0
# 66    37.5
# 72    37.5
# 73    25.0
# 74     0.0
# 84     0.0
# 89    87.5
# 92    12.5
# 94    25.0
# 98    37.5
# Name: %_Geo, dtype: float64

# %%
#4
aprovados_segunda_fase = df[(df['Total_Acertos'] > 45) &~ (df.index.isin(desqualificados.index))]
aprovados_segunda_fase
# Out:
#     Mat  Por  Geo  Ing  His  Fis  Qui      %_Mat      %_Por  %_Geo  %_Ing  \
# 1    19   10    0    0    0   11    8  79.166667  55.555556    0.0    0.0
# 2    14   16    0    5    7    4    4  58.333333  88.888889    0.0   62.5
# 5    20    2    5    3    2    9    9  83.333333  11.111111   62.5   37.5
# 7    18    4    4    7    7    1    8  75.000000  22.222222   50.0   87.5
# 8    22    9    2    7    6    5    7  91.666667  50.000000   25.0   87.5
# 17   21   15    2    2    4    2    6  87.500000  83.333333   25.0   25.0
# 18   20    4    3    5    3   11    4  83.333333  22.222222   37.5   62.5
# 24   20    2    7    5    3   11    2  83.333333  11.111111   87.5   62.5
# 31   15   13    3    1    3    9   10  62.500000  72.222222   37.5   12.5
# 36   22    9    6    6    1    4    8  91.666667  50.000000   75.0   75.0
# 37   19   12    5    7    1    6    2  79.166667  66.666667   62.5   87.5
# 39    4   16    2    4    6    9    8  16.666667  88.888889   25.0   50.0
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-866d798b-6ef1-4805-b26b-ed8744b137c3.c000.csv'
vacAcre= pd.read_csv(
    arquivo,
    sep=';')
vacAcre.head()
# Out:
#                                  document_id  \
# 0  a4208578-d598-4d44-9eda-1cb0aa23775e-i0b0
# 1  dd097975-d896-4adc-97a1-5de3f51792a4-i0b0
# 2  e4592d83-2655-4782-a7a2-261f9147a151-i0b0
# 3  dd180d26-5bee-44d5-a4d5-ea314976d7f1-i0b0
# 4  b63af233-21d8-4af7-9aa9-3f8ff6285753-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  28ca968328b60b50f5db16ea47cd2427e834afec771af8...              16
# 1  5310f2da2074b4d20620f811323a6f7c4fc8853fc5a41f...              22
# 2  fc5e974b409257df8daf776029cdf9c8436188dfad358b...              19
# 3  d0a264fe07e8b95225c45d61cd6f1c020c1dec5d5f1125...              68
# 4  3fdd86b8842269eda2dd906eb0aa15473ae1b5f8e64f1c...              49
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2005-01-28                          F                       99
# 1              1998-08-09                          F                       99
# ...

# %%
# 1) Sua solução aqui
vacAcre.shape[0]
# Out:
# 390911

# %%
# 2)
vacAcre['paciente_id'].nunique()
# Out:
# 318850

# %%
# 3)
primeiraDose = vacAcre['vacina_descricao_dose'].unique()[0]
display(primeiraDose)
QtdPrimeiraDose = vacAcre['paciente_id'].loc[vacAcre['vacina_descricao_dose'] == primeiraDose].nunique()
QtdPrimeiraDose
# Out:
# '1ª Dose'
# 143753

# %%
# 4)

pacientesMenos18 = vacAcre['paciente_id'].loc[vacAcre['paciente_idade'] < 18 ]. nunique()
pacientesMenos18
# Out:
# 69726

# %%
# 5)
fabricante = vacAcre['estabelecimento_razaoSocial'].nunique()
fabricante
# Out:
# 64

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
vacAcre_menor = vacAcre.loc[vacAcre['paciente_idade'] < 18]
display(vacAcre_menor)
# Out:
#                                       document_id  \
# 0       a4208578-d598-4d44-9eda-1cb0aa23775e-i0b0
# 16      a2711709-de7b-47cd-b779-221bcb6fc4a4-i0b0
# 19      ddbe8e75-ac1e-40b7-ad55-ead506189efd-i0b0
# 34      a25d31f9-c03e-4f65-87f3-59e54a454cdd-i0b0
# 36      a5d9dd07-0bb1-42e2-ba28-cbd3eb661839-i0b0
# ...                                           ...
# 390888  c67be324-62ec-4c56-a24d-bf52cecd8bc5-i0b0
# 390897  c76240fc-b5c7-42fe-b197-5834997c5fe8-i0b0
# 390902  c792701d-7d82-4f07-a441-b04b8d77fc73-i0b0
# 390904  c7a24335-f5de-49dd-836e-3667f8d4bbfa-i0b0
# 390910  c85b7508-d64e-454c-a543-10cdc30c1f8c-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       28ca968328b60b50f5db16ea47cd2427e834afec771af8...              16
# 16      238cc2c7155cfefa484104a14b73046fb1515c5640c96e...              13
# 19      4a502fc943b8e62deca3f6cd1be3885f7b0d8a2ed88796...              14
# ...

# %%
# 2)
ListaColunas = vacAcre_menor.columns
display(ListaColunas)
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3)
vacAcre_menor['vacina_categoria_nome'].nunique()
# Out:
# 14

# %%
# 4)
ListaEstabelecimento = [ListaColunas[14:20]]
ListaEstabelecimento
# Out:
# [Index(['estabelecimento_valor', 'estabelecimento_razaoSocial',
#         'estalecimento_noFantasia', 'estabelecimento_municipio_codigo',
#         'estabelecimento_municipio_nome', 'estabelecimento_uf'],
#        dtype='object')]

# %%
# 5)
vacAcre_menor_lista = vacAcre_menor.loc[:, ListaEstabelecimento[0]]
vacAcre_menor_lista.head()
# Out:
#     estabelecimento_valor              estabelecimento_razaoSocial  \
# 0                 6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 16                7561113  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 19                2001349        PREFEITURA MUNICIPAL DE BRASILEIA
# 34                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 36                2000903   PREFEITURA MUNICIPAL DE SENA MADUREIRA
#
#                              estalecimento_noFantasia  \
# 0   DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 16     UNIDADE BASICA DE SAUDE EUCLIDES QUEIROS FILHO
# 19                             ESF TUFIC MIZAEL SAADY
# 34  DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 36  UNIDADE BASICA DE SAUDE FLORLIRIO PEREIRA LUSTOSA
#
#     estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 0                             120040                     RIO BRANCO
# 16                            120020                CRUZEIRO DO SUL
# ...

# %%
#6
vacAcre_menor_lista['Qtd_Vacinas'] = vacAcre_menor_lista.groupby('estalecimento_noFantasia')['estalecimento_noFantasia'].transform('count')
vacAcre_menor_lista

dfFinal=vacAcre_menor_lista.drop_duplicates()
dfFinal
# Out:
#         estabelecimento_valor                 estabelecimento_razaoSocial  \
# 0                     6917291          PREFEITURA MUNICIPAL DE RIO BRANCO
# 16                    7561113     PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 19                    2001349           PREFEITURA MUNICIPAL DE BRASILEIA
# 36                    2000903      PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 53                    2000059               PREFEITURA MUNICIPAL DE FEIJO
# ...                       ...                                         ...
# 201440                2001357  SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA
# 238646                4646770                           USF SAO FRANCISCO
# 340019                6411312   PREFEITURA MUNICIPAL DE PLACIDO DE CASTRO
# 359337                2000814       SECRETARIA DE ESTADO DE SAUDE DO ACRE
# 370287                2832798      PREFEITURA MUNICIPAL DE EPITACIOLANDIA
#
#                                  estalecimento_noFantasia  \
# ...

# %%
# Encontra linhas duplicadas com base na coluna 'estalecimento_noFantasia'
linhas_duplicadas = dfFinal.duplicated(subset=['estalecimento_noFantasia'], keep= False)

# Exibe as linhas duplicadas
display(dfFinal[linhas_duplicadas])
# Out:
#      estabelecimento_valor       estabelecimento_razaoSocial  \
# 60                 6612385  PREFEITURA MUNICIPAL DE TARAUACA
# 559                6612385             POLO BASE DE TARAUACA
#
#                               estalecimento_noFantasia  \
# 60   UNIDADE ASSISTENCIAL A SAUDE INDIGENA DE TARAU...
# 559  UNIDADE ASSISTENCIAL A SAUDE INDIGENA DE TARAU...
#
#      estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# 60                             120060                       TARAUACA
# 559                            120060                       TARAUACA
#
#     estabelecimento_uf  Qtd_Vacinas
# 60                  AC          844
# 559                 AC          844
